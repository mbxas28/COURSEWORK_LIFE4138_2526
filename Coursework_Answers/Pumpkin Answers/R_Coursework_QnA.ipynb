# %% [markdown]
# # R Coursework part 1

# %% [markdown]
# Answer all of the questions below in the cells provided.
#
# Make sure you:
#
# - comment your code
# - run your cells to check your answers
# - save your notebook with your answers before submitting it

# %% [markdown]
# ### Question 1

# %% [markdown]
# Create a data frame with 5 rows and 2 columns. The first column should be a vector of names of your choice, the second should be a series of numeric values.

# %%
animal <- c("Aardvark", "Koala", "Platypus", "Iguana", "Lynx")
individuals <- c(4, 26, 38, 15, 3)
df <- data.frame(animal, individuals)
data.frame(animal, individuals)
# Out:
#   animal   individuals
# 1 Aardvark  4
# 2 Koala    26
# 3 Platypus 38
# 4 Iguana   15
# 5 Lynx      3

# %% [markdown]
# ### Question 2

# %% [markdown]
# The code in the cell below provides examples of each of the main data structures in R. Run the code in the cell below.

# %%
my_vector <- seq(from = 1, to = 1000, by = 1)
my_matrix <- matrix(1:100, nrow = 10, ncol = 10)
my_dataframe <- data.frame(name = rep(c("a", "b"), each = 10), value = 21:40)
my_list <- list(my_vector, my_matrix, my_dataframe)

# %% [markdown]
# Show how to access:
#
# - The 4th value of the vector
# - Column 4 and row 7 of the matrix
# - The 10th value of name in the data.frame
# - The 5th element of the 1st element of the list

# %%
#the 4th value of the vector
my_vector[4]

#column 4 and row 7 of the matrix
my_matrix[7 , 4]

#the 10th value of name in the data frame
my_dataframe$name[10]

#the 5th element of the 1st element of the list
my_list[[1]][5]
# Out:
# [1] 4
# [1] 37
# [1] "a"
# [1] 5

# %% [markdown]
# ### Question 3

# %% [markdown]
# Show three different ways to print the numbers 200 to 300 in R. One should be a `for` loop, one should be an `sapply` function and the third can be a method of your choosing.

# %%
#using for loop
for (n in 200:300){
  print
}

#using sapply
number2 <- 200:300
sapply(number2, print)

#using print
number3 <- 200:300
print(number3)
# Out:
# [1] 200
# [1] 201
# [1] 202
# [1] 203
# [1] 204
# [1] 205
# [1] 206
# [1] 207
# [1] 208
# [1] 209
# [1] 210
# [1] 211
# [1] 212
# [1] 213
# [1] 214
# [1] 215
# [1] 216
# [1] 217
# [1] 218
# [1] 219
# [1] 220
# [1] 221
# [1] 222
# [1] 223
# [1] 224
# [1] 225
# [1] 226
# [1] 227
# [1] 228
# [1] 229
# [1] 230
# [1] 231
# [1] 232
# [1] 233
# [1] 234
# [1] 235
# [1] 236
# [1] 237
# [1] 238
# [1] 239
# [1] 240
# [1] 241
# [1] 242
# [1] 243
# [1] 244
# [1] 245
# [1] 246
# [1] 247
# [1] 248
# [1] 249
# [1] 250
# [1] 251
# [1] 252
# [1] 253
# [1] 254
# [1] 255
# [1] 256
# [1] 257
# [1] 258
# [1] 259
# [1] 260
# [1] 261
# [1] 262
# [1] 263
# [1] 264
# [1] 265
# [1] 266
# [1] 267
# [1] 268
# [1] 269
# [1] 270
# [1] 271
# [1] 272
# [1] 273
# [1] 274
# [1] 275
# [1] 276
# [1] 277
# [1] 278
# [1] 279
# [1] 280
# [1] 281
# [1] 282
# [1] 283
# [1] 284
# [1] 285
# [1] 286
# [1] 287
# [1] 288
# [1] 289
# [1] 290
# [1] 291
# [1] 292
# [1] 293
# [1] 294
# [1] 295
# [1] 296
# [1] 297
# [1] 298
# [1] 299
# [1] 300
#   [1] 200 201 202 203 204 205 206 207 208 209 210 211 212 213 214 215 216 217
#  [19] 218 219 220 221 222 223 224 225 226 227 228 229 230 231 232 233 234 235
#  [37] 236 237 238 239 240 241 242 243 244 245 246 247 248 249 250 251 252 253
#  [55] 254 255 256 257 258 259 260 261 262 263 264 265 266 267 268 269 270 271
#  [73] 272 273 274 275 276 277 278 279 280 281 282 283 284 285 286 287 288 289
#  [91] 290 291 292 293 294 295 296 297 298 299 300
#   [1] 200 201 202 203 204 205 206 207 208 209 210 211 212 213 214 215 216 217
#  [19] 218 219 220 221 222 223 224 225 226 227 228 229 230 231 232 233 234 235
#  [37] 236 237 238 239 240 241 242 243 244 245 246 247 248 249 250 251 252 253
#  [55] 254 255 256 257 258 259 260 261 262 263 264 265 266 267 268 269 270 271
#  [73] 272 273 274 275 276 277 278 279 280 281 282 283 284 285 286 287 288 289
#  [91] 290 291 292 293 294 295 296 297 298 299 300

# %% [markdown]
# ### Question 4

# %% [markdown]
# The following code creates a vector of animal names: (run this code)

# %%
animals <- c("tiger", "lion", "badger", "fox", "rabbit", "fish", "dog", "octopus")

# %% [markdown]
# Show how you would replace the fish and octopus in this dataset with two other animals without creating a new vector.

# %%
#assigning new/replacing old values with new without creating a new vector
#animals_new <- replace(animals, c(6, 8), c("mouse", "shrew"))
animals[6] <- 'mouse'
animals[8] <- 'shrew'
# Out:
# [1] "tiger"  "lion"   "badger" "fox"    "rabbit" "mouse"  "dog"    "shrew"

# %% [markdown]
# ### Question 5

# %% [markdown]
# Using the `cars` dataset, make a `baseR` (i.e. do not use `ggplot2`) scatterplot of speed vs distance Ensure the x and y labels do not include cars$ and give your plot an appropriate title.
#
# HINT: you will have to begin by loading the cars dataset

# %%
data(mtcars)
plot(mtcars$qsec ~ mtcars$disp, main="Speed vs Distance", xlab="Distance (cu.in)", ylab="Car speed (qsec)")
# Out:
# Plot with title “Speed vs Distance”

# %% [markdown]
# ### Question 6

# %% [markdown]
# Using the `starwars` dataset, identify the individuals with:
#
# - the tallest height
# - the lowest mass
#
# HINT: the starwars dataset is part of the dplyr package

# %%
install.packages("dplyr")
library(dplyr)
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
names(starwars)
# Out:
#  [1] "name"       "height"     "mass"       "hair_color" "skin_color"
#  [6] "eye_color"  "birth_year" "sex"        "gender"     "homeworld"
# [11] "species"    "films"      "vehicles"   "starships"

# %%
data_starwars <- starwars

starwars %>%
    arrange(desc(height)) %>%
    slice(1) %>%
    select(name, height)
    
starwars %>%
    arrange(order(mass)) %>%
    slice(1) %>%
    select(name, mass)
# Out:
#   name        height
# 1 Yarael Poof 264
#   name  mass
# 1 Lobot 79

# %% [markdown]
# ### Question 7

# %% [markdown]
# The `dplyr` dataset `storms` is part of the US National Oceanic and Atmospheric Administration database of Atlantic hurricanes. It contains multiple repeated measurements from hurricanes. For a given storm, there are measurements from every 6 hours across the life time of the storm.
#
# Use a tidyverse approach with `dplyr` to answer the following:
#
# - how many different storms are contained in the database?
# - which year had the most storms?
# - which storm, in which year had the highest pressure?
#
# HINT:
# unique() will help ensure you remove duplicated data from a vector e.g.
# x <- c(1, 1, 2, 2, 3, 3, 4, 4)
# unique(x)

# %%
install.packages("tidyverse")
library(tidyverse)
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Warning message:
# “package ‘purrr’ was built under R version 4.5.2”
# Warning message:
# “package ‘stringr’ was built under R version 4.5.2”
# ── Attaching core tidyverse packages ───────────────────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.0     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.2.0
# ── Conflicts ─────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
head(storms)
# Out:
#   name year month day hour lat  long  status              category wind
# 1 Amy  1975 6     27   0   27.5 -79.0 tropical depression NA       25
# 2 Amy  1975 6     27   6   28.5 -79.0 tropical depression NA       25
# 3 Amy  1975 6     27  12   29.5 -79.0 tropical depression NA       25
# 4 Amy  1975 6     27  18   30.5 -79.0 tropical depression NA       25
# 5 Amy  1975 6     28   0   31.5 -78.8 tropical depression NA       25
# 6 Amy  1975 6     28   6   32.4 -78.7 tropical depression NA       25
#   pressure tropicalstorm_force_diameter hurricane_force_diameter
# 1 1013     NA                           NA
# 2 1013     NA                           NA
# 3 1013     NA                           NA
# 4 1013     NA                           NA
# 5 1012     NA                           NA
# 6 1012     NA                           NA

# %%
data(storms)
#names(storms)
#head(as.data.frame(storms))

#how many different storms are contained in the database?

storms %>%
  distinct(name) %>%
  count()
# Out:
# Warning message in data(storms):
# “data set ‘storms’ not found”
# Error in storms %>% distinct(name) %>% count(): could not find function "%>%"
# Traceback:

# %%
#which year had the most storms?

storms %>%
  distinct(name, year) %>%  
  count(year) %>%
  arrange(desc(year)) %>%
  slice(1)
# Out:
#   year n
# 1 2022 16

# %%
#which storm in which year had the highest pressure

storms %>%
  group_by(pressure, name, year) %>%
  count(pressure) %>%
  arrange(desc(pressure)) %>%
  head(1)
# Out:
#   pressure name  year n
# 1 1024     Danny 2003 2

# %% [markdown]
# ### Question 8

# %% [markdown]
# The `ggplot2` dataset `diamonds` contains the price and information from the sale of 54,000 different diamonds. You can use ?diamonds to find out more about the dataset if you want.
#
# Using `ggplot2`:
#
# - plot the relationship between the carat (i.e. the weight of the diamond) and the price.
# - plot a histogram of prices of all the diamonds
# - plot a boxplot of the difference in price between the different cuts

# %%
install.packages("tidyverse")
library(tidyverse)
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Warning message:
# “package ‘purrr’ was built under R version 4.5.2”
# Warning message:
# “package ‘stringr’ was built under R version 4.5.2”
# ── Attaching core tidyverse packages ───────────────────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ forcats   1.0.1     ✔ readr     2.1.5
# ✔ ggplot2   4.0.1     ✔ stringr   1.6.0
# ✔ lubridate 1.9.4     ✔ tibble    3.3.0
# ✔ purrr     1.2.0     ✔ tidyr     1.3.1
# ── Conflicts ─────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
head(diamonds)
# Out:
#   carat cut       color clarity depth table price x    y    z
# 1 0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43
# 2 0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31
# 3 0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31
# 4 0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63
# 5 0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75
# 6 0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48

# %%
#relationship between the carat (i.e. the weight of the diamond) and the price.

ggplot(aes(x = carat, y = price), data = diamonds)+ 
  geom_point() +
  labs(title = 'Relationship Between Carat and Price of Diamonds',
       x = 'Carat',
       y = 'Price')
# Out:
# plot without title

# %%
#plot a histogram of prices of all the diamonds

ggplot(aes(x = price), data = diamonds)+ 
  geom_histogram(binwidth = 300) +
  labs(title = 'Price of all diamonds')
# Out:
# plot without title

# %%
#boxplot of price by cut

ggplot(diamonds, aes(x = cut, y = price)) +
  geom_boxplot() +
    labs(title = "Diamond Price by Cut",
    x = "Cut",
    y = "Price")
# Out:
# plot without title

# %% [markdown]
# ### Question 9

# %% [markdown]
# Identify the maximum and minimum price that the diamonds in the diamonds data set sold for. Add a new column to the diamonds data set that contains the string “Low price” if the value in the price column is less than 5000 dollars and “High price” if it is above 5000 dollars.

# %%
data_diamonds <- diamonds

#finding max and min price of diamond

print("Maximum price at which the diamond is sold at: ")
max(diamonds$price, na.rm = TRUE)

print("Minimum price at which the diamond is sold at: ")
min(diamonds$price, na.rm = TRUE)

#creating a new column based on the condition of price < 5000 and sorting accordingly
test.df <- data_diamonds
test.df$range_price <- ifelse(test.df$price < 5000,"Low Price","High Price")
head(test.df)
# Out:
# [1] "Maximum price at which the diamond is sold at: "
# [1] 18823
# [1] "Minimum price at which the diamond is sold at: "
# [1] 326
#   carat cut       color clarity depth table price x    y    z    range_price
# 1 0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43 Low Price
# 2 0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31 Low Price
# 3 0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31 Low Price
# 4 0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63 Low Price
# 5 0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75 Low Price
# 6 0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48 Low Price

# %% [markdown]
# ### Question 10

# %% [markdown]
# Sticking with the `diamonds` dataset for this question. A carat is a special unit of weight for gemstones where a single carat is 200 mg or 0.2 g. Write a function to convert the `diamonds$carat` vector into grams or milligrams. How heavy is the heaviest diamond?

# %%
#converting carat to gram
diamonds$in_gram <- diamonds$carat * 0.2 
head(diamonds)

print("The heaviest diamond in grams weighs: ")
max(diamonds$in_gram, na.rm = TRUE)
# Out:
#   carat cut       color clarity depth table price x    y    z    in_gram
# 1 0.23  Ideal     E     SI2     61.5  55    326   3.95 3.98 2.43 0.046
# 2 0.21  Premium   E     SI1     59.8  61    326   3.89 3.84 2.31 0.042
# 3 0.23  Good      E     VS1     56.9  65    327   4.05 4.07 2.31 0.046
# 4 0.29  Premium   I     VS2     62.4  58    334   4.20 4.23 2.63 0.058
# 5 0.31  Good      J     SI2     63.3  58    335   4.34 4.35 2.75 0.062
# 6 0.24  Very Good J     VVS2    62.8  57    336   3.94 3.96 2.48 0.048
# [1] "The heaviest diamond in grams weighs: "
# [1] 1.002
